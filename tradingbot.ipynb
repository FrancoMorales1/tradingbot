# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data.csv')
col = ['Timestamp','Open','High','Low','Close']
n = int((df.shape[0]-100000))
d = []
result = []
j=0
for i in range((df.shape[0]-75000),df.shape[0]-4):
    d.append(np.asarray(df.iloc[i:i+3,1]))
    d[j][np.isnan(d[j])]=0

    maxValue = max(d[j])
    if (maxValue < df.iloc[i+4,4]):
        result.append('Comprar')
    elif (maxValue == df.iloc[i+4,4]):
        result.append('Nada')
    else:
        result.append('Vender')
    j=j+1
print(d)
# Out:
# [array([40014.3 , 40020.09, 39999.  ]), array([40020.09, 39999.  , 40021.29]), array([39999.  , 40021.29, 40093.13]), array([40021.29, 40093.13, 40155.18]), array([40093.13, 40155.18, 40197.85]), array([40155.18, 40197.85, 40222.23]), array([40197.85, 40222.23, 40235.98]), array([40222.23, 40235.98, 40259.86]), array([40235.98, 40259.86, 40339.09]), array([40259.86, 40339.09, 40355.94]), array([40339.09, 40355.94, 40395.83]), array([40355.94, 40395.83, 40412.4 ]), array([40395.83, 40412.4 , 40443.48]), array([40412.4 , 40443.48, 40451.48]), array([40443.48, 40451.48, 40455.04]), array([40451.48, 40455.04, 40473.04]), array([40455.04, 40473.04, 40418.46]), array([40473.04, 40418.46, 40404.67]), array([40418.46, 40404.67, 40410.17]), array([40404.67, 40410.17, 40368.4 ]), array([40410.17, 40368.4 , 40362.51]), array([40368.4 , 40362.51, 40337.34]), array([40362.51, 40337.34, 40362.96]), array([40337.34, 40362.96, 40326.81]), array([40362.96, 40326.81, 40317.14]), array([40326.81, 40317.14, 40298.51]), array([40317.14, 40298.51, 40293.07]), array([40298.51, 40293.07, 40305.97]), array([40293.07, 40305.97, 40296.41]), array([40305.97, 40296.41, 40313.1 ]), array([40296.41, 40313.1 , 40363.43]), array([40313.1 , 40363.43, 40330.  ]), array([40363.43, 40330.  , 40315.  ]), array([40330.  , 40315.  , 40245.91]), array([40315.  , 40245.91, 40297.11]), array([40245.91, 40297.11, 40355.07]), array([40297.11, 40355.07, 40340.87]), array([40355.07, 40340.87, 40314.15]), array([40340.87, 40314.15, 40284.99]), array([40314.15, 40284.99, 40317.  ]), array([40284.99, 40317.  , 40309.58]), array([40317.  , 40309.58, 40309.58]), array([40309.58, 40309.58, 40317.07]), array([40309.58, 40317.07, 40255.77]), array([40317.07, 40255.77, 40200.  ]), array([40255.77, 40200.  , 40241.35]), array([40200.  , 40241.35, 40216.14]), array([40241.35, 40216.14, 40175.  ]), array([40216.14, 40175.  , 40162.5 ]), array([40175. , 40162.5, 40140. ]), array([40162.5, 40140. , 40160. ]), array([40140.  , 40160.  , 40172.38]), array([40160.  , 40172.38, 40170.  ]), array([40172.38, 40170.  , 40051.71]), array([40170.  , 40051.71, 40036.88]), array([40051.71, 40036.88, 40079.39]), array([40036.88, 40079.39, 40051.96]), array([40079.39, 40051.96, 40033.88]), array([40051.96, 40033.88, 39833.19]), array([40033.88, 39833.19, 39881.44]), array([39833.19, 39881.44, 39788.69]), array([39881.44, 39788.69, 39889.57]), array([39788.69, 39889.57, 39870.96]), array([39889.57, 39870.96, 39895.04]), array([39870.96, 39895.04, 39877.31]), array([39895.04, 39877.31, 39830.15]), array([39877.31, 39830.15, 39819.01]), array([39830.15, 39819.01, 39755.41]), array([39819.01, 39755.41, 39602.93]), array([39755.41, 39602.93, 39674.97]), array([39602.93, 39674.97, 39675.88]), array([39674.97, 39675.88, 39544.65]), array([39675.88, 39544.65, 39405.62]), array([39544.65, 39405.62, 39398.86]), array([39405.62, 39398.86, 39523.42]), array([39398.86, 39523.42, 39513.27]), array([39523.42, 39513.27, 39514.49]), array([39513.27, 39514.49, 39471.71]), array([39514.49, 39471.71, 39334.33]), array([39471.71, 39334.33, 39407.5 ]), array([39334.33, 39407.5 , 39354.42]), array([39407.5 , 39354.42, 39367.15]), array([39354.42, 39367.15, 39378.38]), array([39367.15, 39378.38, 39402.14]), array([39378.38, 39402.14, 39381.83]), array([39402.14, 39381.83, 39357.35]), array([39381.83, 39357.35, 39364.6 ]), array([39357.35, 39364.6 , 39369.31]), array([39364.6 , 39369.31, 39362.61]), array([39369.31, 39362.61, 39432.48]), array([39362.61, 39432.48, 39442.87]), array([39432.48, 39442.87, 39325.95]), array([39442.87, 39325.95, 39374.71]), array([39325.95, 39374.71, 39365.62]), array([39374.71, 39365.62, 39280.64]), array([39365.62, 39280.64, 39300.  ]), array([39280.64, 39300.  , 39305.51]), array([39300.  , 39305.51, 39252.82]), array([39305.51, 39252.82, 39215.02]), array([39252.82, 39215.02, 39156.95]), array([39215.02, 39156.95, 39216.  ]), array([39156.95, 39216.  , 39244.99]), array([39216.  , 39244.99,  ...

# %%
X = d
y = result
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
print(y_pred)
j = -1
arr =[]
for x in y_pred:
    if(x=='Comprar'):
        if(j!=-1 and arr[j][0]=='Comprar'):
            arr[j][1] += 1
        else:
            arr.append(['Comprar',1])
            j+=1
    elif (x=='Vender'):
        if(j!=-1 and arr[j][0]=='Vender'):
            arr[j][1] += 1
        else:
            arr.append(['Vender',1])
            j+=1
# Out:
# ['Comprar' 'Vender' 'Vender' ... 'Vender' 'Vender' 'Vender']

# %%
usdt=100
btc=0.0001
cantCompraBTC=0.0001
cantVentaBTC=0.0001
contadorOportunidadesPerdidasVenta = 0
contadorOportunidadesPerdidasCompra = 0
for x, y in zip(X_test, y_pred):
    if y=='Comprar':
        if (usdt - cantCompraBTC*min(x) >= 0):
            usdt = usdt - cantCompraBTC*min(x)
            btc = btc + cantCompraBTC
        else:
            contadorOportunidadesPerdidasCompra += 1
    elif y=='Vender':
        if(btc - cantVentaBTC >= 0):
            btc = btc - cantVentaBTC
            usdt = usdt + cantVentaBTC*max(x)
        else:
            contadorOportunidadesPerdidasVenta +=1
    else:
        pass
print('Tiempo transcurrido')
print(str(len(y_pred)/(60*24))+'Dias')
print('Plata inicial')
print(str(100 + 0.0001*40020.09)+' USDT')
print('Plata final')
print(str(usdt)+' USDT')
print(str(btc)+' BTC')
print('Ganancia final')
print(str(usdt - 100)+' USDT')
print(str(btc - 0.0001)+' BTC')
print('Ganancia final en dolares')
print(str((usdt - 100) + (btc - 0.0001)*58693.43)+' USDT')
print('Contador oportunidades perdidas de compra')
print(contadorOportunidadesPerdidasCompra)
print('Contador oportunidades perdidas de venta')
print(contadorOportunidadesPerdidasVenta)
# Out:
# Tiempo transcurrido
# 15.624305555555555Dias
# Plata inicial
# 104.002009 USDT
# Plata final
# 487.41906599999965 USDT
# 2.710505431213761e-20 BTC
# Ganancia final
# 387.41906599999965 USDT
# -9.999999999999998e-05 BTC
# Ganancia final en dolares
# 381.54972299999963 USDT
# Contador oportunidades perdidas de compra
# 0
# Contador oportunidades perdidas de venta
# 7708

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.5978487932797013
